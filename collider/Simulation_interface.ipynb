# %% [markdown]
# # Chemical simulation interface
# This notebook provides an interface for a toy model of a chemical reaction in the gas phase.

# %% [markdown]
# ## Import libraries

# %%
from collider import Simulation
from ipycanvas import Canvas

# %% [markdown]
# ## Initialize and run the simulation
# Initialize the Simulation class with the desired parameters and run the simulation loop.

# %%
simulation = Simulation(Canvas, 800, 600, 100, temperature=100)
simulation.canvas
# Out:
# Canvas(height=600, width=800)

# %%
simulation.run()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 simulation.run()
#
# File ~/Documents/Introduction to Data Analytics and Python/DSA101/collider/collider.py:239, in Simulation.run(self)
#     237 def run(self):
#     238     while True:
# --> 239         self.update()
#     240         self.draw()
#     241         time.sleep(0.002)
#
# File ~/Documents/Introduction to Data Analytics and Python/DSA101/collider/collider.py:214, in Simulation.update(self)
#     212     for other in self.spheres:
#     213         if sphere != other:
# --> 214             sphere.check_sphere_collision(other)
#     216     sphere.equilibriate_temperature(self.temperature)
#     218 # remove spheres that are out of bounds (inplace, https://stackoverflow.com/questions/1207406)
#
# File ~/Documents/Introduction to Data Analytics and Python/DSA101/collider/collider.py:104, in ChemicalSphere.check_sphere_collision(self, other)
#      98 def check_sphere_collision(self, other):
#      99     if (
#     100         not isinstance(other, ChemicalSphere)
#     101         or self.atom == other.atom
#     102         or not self.atom.reaction_partner == other.atom.name
#     103     ):
# --> 104         super().check_sphere_collision(other)
#     105         return
#     107     # Pacman version:
#     108     # if not isinstance(other, ChemicalSphere) or \
#     109     #    self.atom == other.atom:
#    (...)    112
#     113     # calculate total kinetic energy
#
# File ~/Documents/Introduction to Data Analytics and Python/DSA101/collider/collider.py:63, in Sphere.check_sphere_collision(self, other)
#      61 dx = self.x - other.x
#      62 dy = self.y - other.y
# ---> 63 distance = np.sqrt(dx**2 + dy**2)
#      64 if distance < self.radius + other.radius:
#      65     # Calculate new velocities based on conservation of momentum and kinetic energy
#      66     nx = dx / distance
#
# KeyboardInterrupt:
